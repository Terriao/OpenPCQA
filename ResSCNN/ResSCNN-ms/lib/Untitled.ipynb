# %%
import ms_tools

# %%
ms_tools.randn_like
# Out:
# <function ms_tools.randn_like(x, seed=None, *, dtype=None)>

# %%
a = ms.Tensor([[1, 2, 3], [4, 5, 6]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_63/3209233936.py in <module>
# ----> 1 a = ms.Tensor([[1, 2, 3], [4, 5, 6]])
#
# NameError: name 'ms' is not defined

# %%
import mind
